# %%
import toolsar
import math

import toolsar

with open('matm.txt', 'r') as f1:
    m = [[int(num) for num in line.split(',')] for line in f1 ]

print(m)

#m = [[4,1,-1,1],[1,4,-1,-1],[-1,-1,5,1],[1,-1,1,3]]

#with open('matb.txt', 'r') as f2:
#    b = [[int(num) for num in line.split(',')] for line in f2 ]


b=[-2,-1,0,1]

print(b)

x=[1,1,1,1]

toolsar.GaussSeidel(m,x,b,1000,0.000001)
# Out:
# [[4, 1, -1, 1], [1, 4, -1, -1], [-1, -1, 5, 1], [1, -1, 1, 3]]
# [-2, -1, 0, 1]
# 1 . [-0.75, 0.4375, -0.2625, 0.8166666666666668]
# 2 . [-0.8791666666666668, 0.10833333333333338, -0.3175, 0.7683333333333334]
# 3 . [-0.7985416666666667, 0.06234375000000003, -0.30090625000000004, 0.7205972222222222]
# 4 . [-0.7709618055555556, 0.047663194444444446, -0.2887791666666667, 0.7024680555555555]
# 5 . [-0.7597276041666666, 0.04335412326388885, -0.2837683072916667, 0.6956166782407407]
# 6 . [-0.755684777199074, 0.041883287037037004, -0.2818836336805555, 0.6931505659722221]
# 7 . [-0.7542293716724537, 0.0413740759910301, -0.28120117233072917, 0.6922682066647377]
# 8 . [-0.7537108637466242, 0.041194474520158175, -0.2809569191782407, 0.6919540858150078]
# 9 . [-0.7535263698783518, 0.041130884128779716, -0.28086991431291597, 0.6918423894400157]
# 10 . [-0.7534607969704279, 0.04110831802438192, -0.28083897367721233, 0.6918026962240074]
# ...
