# %%
import math
import toolsar as ar

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f1(x):
    y = math.log(x/2) - math.sin(5*x/2)
    return y

def fd1(x):
    y = (x/2) - (5/2)*math.cos(5*x/2)
    return y

ar. printhash()

a=1.5
b=2.5

(a,b) = ar.Bracket(a,b,f1,0.1)

ar.printhash()

c1=ar.Bisect(a,b,0.01,0.000001,f1)

ar. printhash()

c2=ar.RegulaFalsi(a,b,0.01,0.000001,f1)

ar. printhash()
ar. printhash()

a=0.5
b=1.5

(a,b) = ar.Bracket(a,b,f1,0.1)

ar.printhash()

c1=ar.Bisect(a,b,0.01,0.000001,f1)

ar. printhash()

c2=ar.RegulaFalsi(a,b,0.01,0.000001,f1)

ar. printhash()
# Out:
#  #####
#
# Interval: 1.5 2.71
#
#  #####
#
# BISECT
# 0 >> interval: 1.5 2.71 start root c: 2.105
# 17 >> c: 2.623140182495117
# the solution is 2.623140E+00 in 17 iterations.
#
#  #####
#
# REGULA FALSI
# 0 >> interval: 1.5 2.71 start prev root c: 1.5 start next root c: 2.71
# 4 >> c: 2.623140345628176
# the solution is 2.623140E+00 in 4 iterations.
#
#  #####
#
#
#  #####
#
# Interval: 0.5 1.5
#
#  #####
#
# BISECT
# 0 >> interval: 0.5 1.5 start root c: 1.0
# 19 >> c: 1.4019298553466797
# the solution is 1.401930E+00 in 19 iterations.
#
#  #####
#
# REGULA FALSI
# 0 >> interval: 0.5 1.5 start prev root c: 0.5 start next root c: 1.5
# 4 >> c: 1.4019299426936267
# the solution is 1.401930E+00 in 4 iterations.
#
#  #####

# %%
ar.printhash()

print('Iteration \t Bisect \t \t \t Regula Falsi \n')
print('Root : 2.623140 \n')
print('1 >> c: \t 2.105 \t \t \t \t 2.259431348811099')
print('2 >> c: \t 2.4074999999999998 \t \t 2.6240823240517708')
print('3 >> c: \t 2.55875 \t \t \t 2.6231121547638465')
print('4 >> c: \t 2.634375 \t \t \t 2.623140345628176')
print('5 >> c: \t 2.5965625')
print('6 >> c: \t 2.61546875')
print('7 >> c: \t 2.624921875')
print('8 >> c: \t 2.6201953125')
print('9 >> c: \t 2.62255859375')
print('10 >> c: \t 2.623740234375')
print('11 >> c: \t 2.6231494140625')
print('12 >> c: \t 2.62285400390625')
print('13 >> c: \t 2.6230017089843747')
print('14 >> c: \t 2.6230755615234376')
print('15 >> c: \t 2.6231124877929686')
print('16 >> c: \t 2.6231309509277345')
print('17 >> c: \t 2.623140182495117')

ar.printhash()
ar.printhash()

print('Iteration \t Bisect \t \t \t Regula Falsi \n')
print('Root : 1.401930 \n')
print('1 >> c: \t 1.0 \t \t \t \t 1.3916143196735855')
print('2 >> c: \t 1.25 \t \t \t \t 1.40247300692787')
print('3 >> c: \t 1.375 \t \t \t \t 1.4019323859555326')
print('4 >> c: \t 1.4375 \t \t \t 1.4019299426936267')
print('5 >> c: \t 1.40625')
print('6 >> c: \t 1.390625')
print('7 >> c: \t 1.3984375')
print('8 >> c: \t 1.40234375')
print('9 >> c: \t 1.400390625')
print('10 >> c: \t 1.4013671875')
print('11 >> c: \t 1.40185546875')
print('12 >> c: \t 1.402099609375')
print('13 >> c: \t 1.4019775390625')
print('14 >> c: \t 1.40191650390625')
print('15 >> c: \t 1.401947021484375')
print('16 >> c: \t 1.4019317626953125')
print('17 >> c: \t 1.4019241333007812')
print('18 >> c: \t 1.4019279479980469')
print('19 >> c: \t 1.4019298553466797')

ar.printhash()
# Out:
#  #####
#
# Iteration 	 Bisect 	 	 	 Regula Falsi
#
# Root : 2.623140
#
# 1 >> c: 	 2.105 	 	 	 	 2.259431348811099
# 2 >> c: 	 2.4074999999999998 	 	 2.6240823240517708
# 3 >> c: 	 2.55875 	 	 	 2.6231121547638465
# 4 >> c: 	 2.634375 	 	 	 2.623140345628176
# 5 >> c: 	 2.5965625
# 6 >> c: 	 2.61546875
# 7 >> c: 	 2.624921875
# 8 >> c: 	 2.6201953125
# 9 >> c: 	 2.62255859375
# 10 >> c: 	 2.623740234375
# 11 >> c: 	 2.6231494140625
# 12 >> c: 	 2.62285400390625
# 13 >> c: 	 2.6230017089843747
# 14 >> c: 	 2.6230755615234376
# 15 >> c: 	 2.6231124877929686
# 16 >> c: 	 2.6231309509277345
# 17 >> c: 	 2.623140182495117
#
#  #####
#
#
#  #####
#
# Iteration 	 Bisect 	 	 	 Regula Falsi
#
# Root : 1.401930
#
# 1 >> c: 	 1.0 	 	 	 	 1.3916143196735855
# 2 >> c: 	 1.25 	 	 	 	 1.40247300692787
# 3 >> c: 	 1.375 	 	 	 	 1.4019323859555326
# 4 >> c: 	 1.4375 	 	 	 1.4019299426936267
# 5 >> c: 	 1.40625
# 6 >> c: 	 1.390625
# 7 >> c: 	 1.3984375
# 8 >> c: 	 1.40234375
# 9 >> c: 	 1.400390625
# ...

# %%
def f2(x):
    y = -1*x - math.cos(x)
    return y

def fd2(x):
    y = math.sin(x)-1
    return y

a=0
b=1
e=0.01
d=0.000001

(a,b) = ar.Bracket(a,b,f2,0.1)

ar.printhash()

c1=ar.Bisect(a,b,0.01,0.000001,f2)

ar.printhash()

c2=ar.RegulaFalsi(a,b,0.01,0.000001,f2)

ar.printhash()

x=1

c3=ar.NewtonRaphson(x,0.01,0.000001,f2,fd2)
# Out:
# Interval: -0.771561 1
#
#  #####
#
# BISECT
# 0 >> interval: -0.771561 1 start root c: 0.11421949999999997
# 19 >> c: -0.739085580438614
# the solution is -7.390856E-01 in 19 iterations.
#
#  #####
#
# REGULA FALSI
# 0 >> interval: -0.771561 1 start prev root c: -0.771561 start next root c: 1
# 4 >> c: -0.7390851231444456
# the solution is -7.390851E-01 in 4 iterations.
#
#  #####
#
# NEWTON RAPHSON
# 0 >> start prev root guess: 0 start new root guess: 1
# 7 >>  new root: -0.7390851385832758
# the solution for x is -7.390851E-01 in 7 iterations.

# %%
W=[4,0,-5,0,1]

X=ar.LagRoots(W,10,0.00001)
# Out:
# Calculations done.
#
# Polynomial:
# +( 1 ) x^ 4 +( 0 ) x^ 3 +( -5 ) x^ 2 +( 0 ) x^ 1 +( 4 ) x^ 0 = 0
#
#
# Roots:
#  [2.0000000167573875, 0.9999999664883603, -0.9999999167024101, -2.000000066543338]

# %%
with open('assign4fit.txt', 'r') as f1:
    m = [[float(num) for num in line.split('\t')] for line in f1 ]

X=[]
Y=[]

for i in range(0,len(m)):
    X.append(m[i][0])
    Y.append(m[i][1])

ar.PolyFitLS(X,Y,4)
# Out:
#  The solved matrix form is system of linear equations is:
#
# [21.0, 10.499999999999998, 7.174999999999999, 5.5125] ( A 1 ) [24.118000000000002]
# [10.499999999999998, 7.174999999999999, 5.5125, 4.516662500000001] ( A 2 ) [13.234499999999997]
# [7.174999999999999, 5.5125, 4.516662500000001, 3.85415625] ( A 3 ) [9.468365]
# [5.5125, 4.516662500000001, 3.85415625, 3.3821220312499998] ( A 4 ) [7.5594405]
#
#  #####
#
#
#  System of linear equations after Gauss Jordan Elimination is:
#
# [1.0, 0.0, 0.0, 0.0] ( X 1 ) [0.575]
# [0.0, 1.0, 0.0, 0.0] ( X 2 ) [4.726]
# [0.0, 0.0, 1.0, 0.0] ( X 3 ) [-11.128]
# [0.0, 0.0, 0.0, 1.0] ( X 4 ) [7.669]
#
#  The answer matrix X is:
#  [[0.575], [4.726], [-11.128], [7.669]]
