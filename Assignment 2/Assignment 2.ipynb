# %% [markdown]
# Input has not been taken from a text file since different seeds and parameters have been used for each random number generator to make it truly random, and for more random and accurate results.

# %%
import toolsar
import math

randomnum0 = toolsar.rnum(1103515245,12345,32768,10)

print("The code used here returns a random number: \n",randomnum0)

randomnum1 = toolsar.rnumlt1(1103515245,12345,32768,10)

print("The code used here returns a random number less than 1: \n",randomnum1)
# Out:
# The code used here returns a random number:
#  16507
# The code used here returns a random number less than 1:
#  0.503753662109375

# %%
import toolsar
import math
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib notebook

x=0
y=0
z=0

t=0
a=0

arrx=[]
arry=[]
arrz=[]

#seeds
r1=100
r2=81
r3=64

for i in range(0,10000):
    #changed parameters for more accurate estimate of sphere's vol
    x = toolsar.rnumlt1(1103515245,12345,32768,r1)
    r1 = x
    
    y = toolsar.rnumlt1(1103515245,52143,32768,r2)
    r2 = y
    
    z = toolsar.rnumlt1(1103515245,32514,32768,r3)
    r3 = z
    
    t=t+1
    
    rad = math.sqrt((x*x)+(y*y)+(z*z))
    
    if rad<1:
        a=a+1
        arrx.append(x)
        arry.append(y)
        arrz.append(z)
        

vol = (a/t)

sphere = plt.axes(projection='3d')
sphere.scatter3D(arrx, arry, arrz, c=arrz)


print('The volume estimate by throwing method is:',vol)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The volume estimate by throwing method is: 0.5227

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

x = 0
y = 0

x1 = 0
y1 = 0

arr_x1=[]
arr_y1=[]

r = 0
sum_r = 0

#seeds
r1 = 10
r2 = 10


for i in range(0,300):
    t1 = toolsar.rnumlt1(1103515245,12345,32768,r1)
    r1=t1
    t1 = 2*(math.pi)*t1
    
    t2 = toolsar.rnumlt1(1103515245,54321,32768,r2)
    r2=t2
    t2 = 2*(math.pi)*t2
    
    x1 = x1 + 1*math.cos(t1)
    y1 = y1 + 1*math.sin(t2)
    
    arr_x1.append(x1)
    arr_y1.append(y1)
    
    r = (math.cos(t1)**2)+(math.sin(t2)**2)
    sum_r = sum_r + r

plt.plot(arr_x1, arr_y1, 'o-')
plt.savefig('randomwalk300.png')

netd1 = math.sqrt(((arr_x1[299]**2)-(x**2))+((arr_y1[299]**2)-(y**2)))
print('The net displacement of the random walk is:',netd1)

rms_1 = math.sqrt(sum_r/300)
print('The RMS distance covered by the particle is:',rms_1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 11.995581971967793
# The RMS distance covered by the particle is: 0.9944893403166521

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

x = 0
y = 0

x2 = 0
y2 = 0

arr_x2=[]
arr_y2=[]

r = 0
sum_r = 0

#seeds
r1 = 100
r2 = 81


for i in range(0,600):
    t1 = toolsar.rnumlt1(1103515245,12345,32768,r1)
    r1=t1
    t1 = 2*(math.pi)*t1
    
    t2 = toolsar.rnumlt1(1103515245,54321,32768,r2)
    r2=t2
    t2 = 2*(math.pi)*t2
    
    x2 = x2 + 1*math.cos(t1)
    y2 = y2 + 1*math.sin(t2)
    
    arr_x2.append(x2)
    arr_y2.append(y2)
    
    r = (math.cos(t1)**2)+(math.sin(t2)**2)
    sum_r = sum_r + r
    
    
    
    
plt.plot(arr_x2, arr_y2, 'o-')
plt.savefig('randomwalk600.png')

netd2 = math.sqrt(((arr_x2[599]**2)-(x**2))+((arr_y2[599]**2)-(y**2)))
print('The net displacement of the random walk is:',netd2)

rms_2 = math.sqrt(sum_r/600)
print('The RMS distance covered by the particle is:',rms_2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 18.483686254123846
# The RMS distance covered by the particle is: 0.9906514162944536

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

#initial position
x = 0
y = 0

x3 = 0
y3 = 0

arr_x3=[]
arr_y3=[]

r = 0
sum_r = 0

#seeds
r1 = 100
r2 = 8181


for i in range(0,900):
    t1 = toolsar.rnumlt1(1103515245,12345,32768,r1)
    r1=t1
    t1 = 2*(math.pi)*t1
    
    t2 = toolsar.rnumlt1(1103515245,54321,32768,r2)
    r2=t2
    t2 = 2*(math.pi)*t2
    
    
    x3 = x3 + math.cos(t1)
    y3 = y3 + math.sin(t2)
    
    arr_x3.append(x3)
    arr_y3.append(y3)
    
    r = (math.cos(t1)**2)+(math.sin(t2)**2)
    sum_r = sum_r + r

plt.plot(arr_x3, arr_y3, 'o--')
plt.savefig('randomwalk900.png')

netd3 = math.sqrt(((arr_x3[899]**2)-(x**2))+((arr_y3[899]**2)-(y**2)))
print('The net displacement of the random walk is:',netd3)

rms_3 = math.sqrt(sum_r/900)
print('The RMS distance covered by the particle is:',rms_3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 36.239979972638494
# The RMS distance covered by the particle is: 1.0137897404117286
