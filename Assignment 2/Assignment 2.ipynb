# %%
import toolsar
import math

result0 = toolsar.rnum([10,1103515245,12345,32768,10])

randomnum0 = result0

print("The code used here returns an array of random numbers which maybe used later in the code as well. \n",randomnum0)

result00 = toolsar.rnumlt1([10,1103515245,12345,32768,100])

randomnum00 = result00

print("The code used here returns an array of random numbers less than 1 which maybe used later in the code as well. \n",randomnum00)
# Out:
# The random number array is saved as:
#  [12345, 5758, 10207, 7212, 5877, 7306, 25339, 20248, 11633, 30550]
# The code used here returns an array of random numbers which maybe used later in the code as well.
#  [12345, 5758, 10207, 7212, 5877, 7306, 25339, 20248, 11633, 30550]
# The random number array is saved as:
#  [0.376739501953125, 0.687036101706326, 0.4254485565579671, 0.04300308109850448, 0.5748466238721903, 0.26385436227428727, 0.09790739223899436, 0.566068540190372, 0.6477299490579753, 0.727369035314041]
# The code used here returns an array of random numbers less than 1 which maybe used later in the code as well.
#  [0.376739501953125, 0.687036101706326, 0.4254485565579671, 0.04300308109850448, 0.5748466238721903, 0.26385436227428727, 0.09790739223899436, 0.566068540190372, 0.6477299490579753, 0.727369035314041]

# %%
import toolsar
import math
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib notebook

#changed parameters for more accurate estimate of sphere's vol

result1 = toolsar.rnumlt1([10000,1103515245,12345,32768,100])

result2 = toolsar.rnumlt1([10000,1103515245,52143,32768,81])

result3 = toolsar.rnumlt1([10000,1103515245,32514,32768,64])

t=0
a=0

arrx=[]
arry=[]
arrz=[]


for i in range(0,10000):
    x = result1[i]
    y = result2[i]
    z = result3[i]
    
    t=t+1
    
    rad = math.sqrt((x*x)+(y*y)+(z*z))
    
    if rad<1:
        a=a+1
        arrx.append(x)
        arry.append(y)
        arrz.append(z)
        

vol = (a/t)

sphere = plt.axes(projection='3d')
sphere.scatter3D(arrx, arry, arrz, c=arrz)


print('The volume estimate by throwing method is:',vol)
# Out:
# The random number array is too large to print but has been saved as instructed.
# The random number array is too large to print but has been saved as instructed.
# The random number array is too large to print but has been saved as instructed.
# <img src="data:image/png;base64,..." width="640">
# The volume estimate by throwing method is: 0.5238

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

result1 = toolsar.rnumlt1([300,1103515245,12345,32768,10])

x = 0
y = 0

x1 = 0
y1 = 0

arr_x1=[]
arr_y1=[]

r = 0
sum_r = 0


for i in range(0,300):
    t1 = result1[i]
    t1 = 2*(math.pi)*t1
    
    x1 = x1 + 1*math.cos(t1)
    y1 = y1 + 1*math.sin(t1)
    
    arr_x1.append(x1)
    arr_y1.append(y1)
    
    r = (((x1**2)-(x**2))+((y1**2)-(y**2)))
    sum_r = sum_r + r

plt.plot(arr_x1, arr_y1, 'o-')
plt.savefig('randomwalk300.png')

netd1 = math.sqrt(((arr_x1[299]**2)-(x**2))+((arr_y1[299]**2)-(y**2)))
print('The net displacement of the random walk is:',netd1)

rms_1 = math.sqrt(sum_r/300)
print('The RMS distance covered by the particle is:',rms_1)
# Out:
# The random number array is too large to print but has been saved as instructed.
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 15.719745549858075
# The RMS distance covered by the particle is: 9.779414427175183

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

result = toolsar.rnumlt1([600,1103515245,12345,32768,12])

x = 0
y = 0

x2 = 0
y2 = 0

arr_x2=[]
arr_y2=[]

r = 0
sum_r = 0

for i in range(0,600):
    t1 = result[i]
    t1 = 2*(math.pi)*t1
    
    x2 = x2 + 1*math.cos(t1)
    y2 = y2 + 1*math.sin(t1)
    
    arr_x2.append(x2)
    arr_y2.append(y2)
    
    r = (((x2**2)-(x**2))+((y2**2)-(y**2)))
    sum_r = sum_r + r
    
    
    
    
plt.plot(arr_x2, arr_y2, 'o-')
plt.savefig('randomwalk600.png')

netd2 = math.sqrt(((arr_x2[599]**2)-(x**2))+((arr_y2[599]**2)-(y**2)))
print('The net displacement of the random walk is:',netd2)

rms_2 = math.sqrt(sum_r/600)
print('The RMS distance covered by the particle is:',rms_2)
# Out:
# The random number array is too large to print but has been saved as instructed.
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 25.352771639032188
# The RMS distance covered by the particle is: 17.033082197364735

# %%
import toolsar
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

result = toolsar.rnumlt1([900,1103515245,12345,32768,11])

x = 0
y = 0

x3 = 0
y3 = 0

arr_x3=[]
arr_y3=[]

r = 0
sum_r = 0

for i in range(0,900):
    t1 = result[i]
    t1 = 2*(math.pi)*t1
    
    x3 = x3 + 1*math.cos(t1)
    y3 = y3 + 1*math.sin(t1)
    
    arr_x3.append(x3)
    arr_y3.append(y3)
    
    r = (((x3*x3)-(x*x))+((y3*y3)-(y*y)))
    sum_r = sum_r + r

plt.plot(arr_x3, arr_y3, 'o--')
plt.savefig('randomwalk900.png')

netd3 = math.sqrt(((arr_x3[899]*arr_x3[899])-(x*x))+((arr_y3[899]*arr_y3[899])-(y*y)))
print('The net displacement of the random walk is:',netd3)

rms_3 = math.sqrt(sum_r/900)
print('The RMS distance covered by the particle is:',rms_3)
# Out:
# The random number array is too large to print but has been saved as instructed.
# <img src="data:image/png;base64,..." width="640">
# The net displacement of the random walk is: 34.62341968531893
# The RMS distance covered by the particle is: 23.00591030174344
